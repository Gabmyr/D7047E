# %%
from ultralytics import YOLO
import cv2
import os
import matplotlib.pyplot as plt
import random
import torch
import imgaug.augmenters as iaa

model = YOLO("yolov9e.pt")  # Load of pretrained "yolov9e" model

# %%
print(model.names)  # This will show all class names the model can detect
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %%
# Specify the path to the 'images' folder
folder_path = "./images"

# Specify the output folder for processed images
output_folder = "./Processed images"

# Check if the output folder exists, and if not, create it
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# List all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]

# %%
# Function to process an individual image and return the processed image
def process_image(image_file):
    image_path = os.path.join(folder_path, image_file)
    img = cv2.imread(image_path)
    results = model(img)
    return img, results

# %%
def draw_bounding_boxes(image, results):
    
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0] #x1, y1, x2 and y2 represents the corners of the detected object
            centroid_x = (x1 + x2) / 2
            centroid_y = (y1 + y2) / 2
            w = x2 - x1
            h = y2 - y1

            image = cv2.rectangle(image, (int(x1), int(y1), int(w), int(h)), (0, 255, 0), 2)
            image = cv2.circle(image, (int(centroid_x), int(centroid_y)), 8, (255, 0, 0), -1)

    return image

# %%
def display_example_images(output_folder, num_images=3):
    processed_image_paths = [os.path.join(output_folder, f) for f in os.listdir(output_folder) if f.startswith("processed_")]
    
    if num_images > len(processed_image_paths):
        num_images = len(processed_image_paths)

    # Randomly shuffle the list of processed image paths
    random.shuffle(processed_image_paths)

    for i in range(num_images):
        image = cv2.imread(processed_image_paths[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        plt.figure(figsize=(8, 8))
        plt.imshow(image)
        plt.axis('off')
        plt.title(f"Processed Image {i+1}")
        plt.show()

# %%
# Process and save all images
for image_file in image_files:
    img, results = process_image(image_file)
    processed_image = draw_bounding_boxes(img, results)
    output_path = os.path.join(output_folder, "processed_" + image_file)
    cv2.imwrite(output_path, processed_image)
# Out:
# 0: 384x640 (no detections), 967.7ms
# Speed: 5.4ms preprocess, 967.7ms inference, 684.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 927.3ms
# Speed: 2.5ms preprocess, 927.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 983.9ms
# Speed: 3.2ms preprocess, 983.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 898.8ms
# Speed: 2.1ms preprocess, 898.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 946.5ms
# Speed: 4.0ms preprocess, 946.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 885.7ms
# Speed: 3.2ms preprocess, 885.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 906.5ms
# Speed: 3.3ms preprocess, 906.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 818.0ms
# Speed: 2.0ms preprocess, 818.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 852.0ms
# Speed: 1.0ms preprocess, 852.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 842.4ms
# Speed: 2.6ms preprocess, 842.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 858.2ms
# Speed: 1.2ms preprocess, 858.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 848.6ms
# Speed: 4.3ms preprocess, 848.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 889.6ms
# Speed: 3.2ms preprocess, 889.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 871.9ms
# Speed: 2.0ms preprocess, 871.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 839.6ms
# Speed: 2.5ms preprocess, 839.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 826.5ms
# Speed: 2.3ms preprocess, 826.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 868.3ms
# Speed: 3.1ms preprocess, 868.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 906.8ms
# Speed: 2.6ms preprocess, 906.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 870.4ms
# Speed: 4.1ms preprocess, 870.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 868.6ms
# Speed: 2.0ms preprocess, 868.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 871.5ms
# Speed: 2.3ms preprocess, 871.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 852.2ms
# Speed: 2.3ms preprocess, 852.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 844.3ms
# Speed: 3.0ms preprocess, 844.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 856.6ms
# Speed: 2.3ms preprocess, 856.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 841.2ms
# Speed: 2.0ms preprocess, 841.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 854.5ms
# Speed: 4.5ms preprocess, 854.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 893.6ms
# Speed: 3.3ms preprocess, 893.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 922.7ms
# Speed: 2.5ms preprocess, 922.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 900.0ms
# Speed: 3.6ms preprocess, 900.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 886.1ms
# Speed: 2.5ms preprocess, 886.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 872.9ms
# Speed: 2.0ms preprocess, 872.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 860.5ms
# Speed: 3.9ms preprocess, 860.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15480\1544627870.py in <module>
#       1 # Process and save all images
#       2 for image_file in image_files:
# ----> 3     img, results = process_image(image_file)
#       4     processed_image = draw_bounding_boxes(img, results)
#       5     output_path = os.path.join(output_folder, "processed_" + image_file)
#
# ~\AppData\Local\Temp\ipykernel_15480\1605050652.py in process_image(image_file)
#       3     image_path = os.path.join(folder_path, image_file)
#       4     img = cv2.imread(image_path)
# ----> 5     results = model(img)
#       6     return img, results
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\engine\model.py in __call__(self, source, stream, **kwargs)
#     175             (List[ultralytics.engine.results.Results]): A list of prediction results, encapsulated in the Results class.
#     176         """
# --> 177         return self.predict(source, stream, **kwargs)
#     178
#     179     @staticmethod
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\engine\model.py in predict(self, source, stream, predictor, **kwargs)
#     451         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     452             self.predictor.set_prompts(prompts)
# --> 453         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     454
#     455     def track(
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\engine\predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     166             return self.stream_inference(source, model, *args, **kwargs)
#     167         else:
# --> 168             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     169
#     170     def predict_cli(self, source=None, model=None):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\utils\_contextlib.py in generator_context(*args, **kwargs)
#      33             # Issuing `None` to a generator fires it up
#      34             with ctx_factory():
# ---> 35                 response = gen.send(None)
#      36
#      37             while True:
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\engine\predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     246                 # Inference
#     247                 with profilers[1]:
# --> 248                     preds = self.inference(im, *args, **kwargs)
#     249                     if self.args.embed:
#     250                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\engine\predictor.py in inference(self, im, *args, **kwargs)
#     140             else False
#     141         )
# --> 142         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     143
#     144     def pre_transform(self, im):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\nn\autobackend.py in forward(self, im, augment, visualize, embed)
#     451         # PyTorch
#     452         if self.pt or self.nn_module:
# --> 453             y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     454
#     455         # TorchScript
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\nn\tasks.py in forward(self, x, *args, **kwargs)
#      87         if isinstance(x, dict):  # for cases of training and validating while training.
#      88             return self.loss(x, *args, **kwargs)
# ---> 89         return self.predict(x, *args, **kwargs)
#      90
#      91     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\nn\tasks.py in predict(self, x, profile, visualize, augment, embed)
#     105         if augment:
#     106             return self._predict_augment(x)
# --> 107         return self._predict_once(x, profile, visualize, embed)
#     108
#     109     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\nn\tasks.py in _predict_once(self, x, profile, visualize, embed)
#     126             if profile:
#     127                 self._profile_one_layer(m, x, dt)
# --> 128             x = m(x)  # run
#     129             y.append(x if m.i in self.save else None)  # save output
#     130             if visualize:
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\nn\modules\block.py in forward(self, x)
#     594         """Forward pass through RepNCSPELAN4 layer."""
#     595         y = list(self.cv1(x).chunk(2, 1))
# --> 596         y.extend((m(y[-1])) for m in [self.cv2, self.cv3])
#     597         return self.cv4(torch.cat(y, 1))
#     598
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\nn\modules\block.py in <genexpr>(.0)
#     594         """Forward pass through RepNCSPELAN4 layer."""
#     595         y = list(self.cv1(x).chunk(2, 1))
# --> 596         y.extend((m(y[-1])) for m in [self.cv2, self.cv3])
#     597         return self.cv4(torch.cat(y, 1))
#     598
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     213     def forward(self, input):
#     214         for module in self:
# --> 215             input = module(input)
#     216         return input
#     217
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# c:\Users\90539\anaconda3\lib\site-packages\ultralytics\nn\modules\conv.py in forward_fuse(self, x)
#      52     def forward_fuse(self, x):
#      53         """Perform transposed convolution of 2D data."""
# ---> 54         return self.act(self.conv(x))
#      55
#      56
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     458
#     459     def forward(self, input: Tensor) -> Tensor:
# --> 460         return self._conv_forward(input, self.weight, self.bias)
#     461
#     462 class Conv3d(_ConvNd):
#
# c:\Users\90539\anaconda3\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     454                             weight, bias, self.stride,
#     455                             _pair(0), self.dilation, self.groups)
# --> 456         return F.conv2d(input, weight, bias, self.stride,
#     457                         self.padding, self.dilation, self.groups)
#     458
#
# KeyboardInterrupt:
